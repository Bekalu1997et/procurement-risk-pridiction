# %% [markdown]
# # 04 - NLP Contract Analysis
#
# Demonstrate contract summarisation and question answering using the `src.nlp_layer` utilities.

# %%
from src import nlp_layer

contract_text = """The supplier must maintain PCI compliance and provide 30 day notice for service changes. Repeated late deliveries will incur a 5% penalty. Data privacy obligations align with GDPR Article 28."""

summary = nlp_layer.summarize_contract(contract_text)
summary

# %%
nlp_layer.contract_qna("What happens if deliveries are late?", contract_text)
