# %% [markdown]
# # 05 - MLOps Simulation
#
# Simulate the weekly scoring loop and review the resulting alerts and audit logs.

# %%
from src import mlops_loop

weekly_predictions = mlops_loop.run_weekly_scoring()
weekly_predictions.head()

# %%
from src import auditing

auditing.db_connector.fetch_audit_trail(limit=10)
